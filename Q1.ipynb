# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import numpy as np
import string
import os
import re
import pickle

# %%
from sortedcontainers import SortedDict, SortedList, SortedSet
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# # Read From Files

# %%
def getListOfFiles(directory):
    '''
    Parameters:
        directory: type(string)
        
    returns: list of all files in directory with the full path of file
    '''
    
    list_of_files = []
    
    for file_path in os.listdir(directory):
        full_path = os.path.join(directory, file_path)
        if os.path.isfile(full_path):
            list_of_files.append(full_path)
    
    return list_of_files

# %% [markdown]
# # Preprocessing Functions

# %%
def lowercase(data):
    '''
    Parameters:
        data: type(string)
    
    returns: lowercase of data
    '''
    
    return data.lower()

# %%
def perform_word_tokenize(corpus):
    '''
    Parameters:
        corpus: type(string)
    
    returns word-level tokenization of corpus
    '''
    
    return word_tokenize(corpus)

# %%
def remove_stopwords_from_tokens(tokens, stopwords_set):
    '''
    Parameters:
        tokens: type(list)
        stopwords_set: type(set)
    
    returns: tokens without stopwords
    '''
    tokens_sans_stopwords = [x for x in tokens if x not in stopwords_set]
    
    return tokens_sans_stopwords

# %%
def remove_punctuation_from_tokens(tokens):
    '''
    Parameters:
        tokens: type(list)
    
    returns: tokens without punctuation
    '''
    tokens_sans_punctuation = [x.translate(str.maketrans('', '', string.punctuation)) for x in tokens]
    
    return tokens_sans_punctuation

# %%
def remove_blank_space_tokens(tokens):
    '''
    Parameters:
        tokens: type(list)
    
    returns: tokens without blank tokens
    '''
    tokens_sans_blank_space = [x for x in tokens if x!='']
    
    return tokens_sans_blank_space

# %%
def lemmatize_tokens(tokens):
    '''
    Parameters:
        tokens: type(list)
    
    returns: returns unique tokens after lemmatization
    '''
    lemmatizer = WordNetLemmatizer()
    lemmatize_tokens = [lemmatizer.lemmatize(x) for x in tokens]
    unique_lemmatize_tokens = list(dict.fromkeys(lemmatize_tokens))
    
    return unique_lemmatize_tokens

# %%
def preprocess(corpus, stopwords_set, preprocess_type):
    # Convert the text to lower case
    lowercase_corpus = lowercase(corpus)
    #print(len(lowercase_corpus))
    
    # Perform word tokenization (word_tokenize also takes care of whitespace)
    word_tokens = perform_word_tokenize(lowercase_corpus)
    #print(len(word_tokens))
    
    # Remove stopwords from tokens
    word_tokens_sans_stopwords = remove_stopwords_from_tokens(word_tokens, stopwords_set)
    #print(len(word_tokens_sans_stopwords))
    
    # Remove punctuation marks from tokens
    word_tokens_sans_punctuation = remove_punctuation_from_tokens(word_tokens_sans_stopwords)
    #print(len(word_tokens_sans_punctuation))
    
    # Remove blank space tokens
    word_tokens_sans_blank_tokens = remove_blank_space_tokens(word_tokens_sans_punctuation)
    #print(len(word_tokens_sans_blank_tokens))
    
    # Lemmatize tokens
    #word_tokens_final = lemmatize_tokens(word_tokens_sans_blank_tokens)
    #print(len(word_tokens_final))
    
    if preprocess_type=='query':
        return word_tokens_sans_blank_tokens
    return sorted(list(dict.fromkeys(word_tokens_sans_blank_tokens)))

# %% [markdown]
# # Helper Functions

# %%
def create_file_dictionary(list_of_files):
    '''
    Paramteres:
        list_of_files: type(string)
    
    returns: file_dictionary with integer key and path_of_file as value
    '''
    file_dictionary = {}
    for i in range(len(list_of_files)):
        file_dictionary[i] = list_of_files[i]
    
    return file_dictionary

# %%
def create_unigram_inverted_index(file_dictionary, stopwords_set):
    # initialize unigram inverted index
    unigram_inverted_index = SortedDict()
    
    # unigram inverted index
    for doc_ID in range(len(file_dictionary)):
        file = open(file_dictionary[doc_ID], 'r', encoding='utf-8', errors='ignore')
        file_corpus = file.read()
        file.close()
        doc_tokens = preprocess(file_corpus, stopwords_set, 'doc')
        for token in doc_tokens:
            if token in unigram_inverted_index:
                unigram_inverted_index[token][0] += 1
                unigram_inverted_index[token][1].add(doc_ID)
            else:
                unigram_inverted_index[token] = [1, SortedSet([doc_ID])]
    
    # Storing unigram inverted index
    uii_file = open('unigram_inverted_index_pickle_file', 'wb')
    pickle.dump(unigram_inverted_index, uii_file)
    uii_file.close()

# %% [markdown]
# # Boolean Functions

# %%
def xANDy(pos_list_1, pos_list_2):
    result = SortedSet()
    i,j = 0,0
    num_of_operations = 0
    while(i<len(pos_list_1) and j<len(pos_list_2)):
        if pos_list_1[i]==pos_list_2[j]:
            result.add(pos_list_1[i])
            i+=1
            j+=1
        elif pos_list_1[i]<pos_list_2[j]:
            i+=1
        else:
            j+=1
        num_of_operations+=1
    
    return result, num_of_operations

# %%
def xORy(pos_list_1, pos_list_2):
    result = SortedSet()
    i,j = 0,0
    num_of_operations = 0
    while(i<len(pos_list_1) and j<len(pos_list_2)):
        if pos_list_1[i]==pos_list_2[j]:
            result.add(pos_list_1[i])
            i+=1
            j+=1
        elif pos_list_1[i]<pos_list_2[j]:
            result.add(pos_list_1[i])
            i+=1
        else:
            result.add(pos_list_2[j])
            j+=1
        num_of_operations+=1
    
    while(i<len(pos_list_1)):
        result.add(pos_list_1[i])
        i+=1
    while(j<len(pos_list_2)):
        result.add(pos_list_2[j])
        j+=1
    
    return result, num_of_operations

# %%
def xANDNOTy(pos_list_1, pos_list_2):
    result = SortedSet()
    i,j = 0,0
    num_of_operations = 0
    while(i<len(pos_list_1) and j<len(pos_list_2)):
        if pos_list_1[i]==pos_list_2[j]:
            i+=1
            j+=1
        elif pos_list_1[i]<pos_list_2[j]:
            result.add(pos_list_1[i])
            i+=1
        else:
            j+=1
        num_of_operations+=1
    
    while(i<len(pos_list_1)):
        result.add(pos_list_1[i])
        i+=1
    
    return result, num_of_operations

# %%
def xORNOTy(pos_list_1, pos_list_2, u_list):
    num_of_not_operations = 0
    i,j = 0,0
    not_pos_list_2 = SortedSet()
    while(i<len(pos_list_2) and j<len(u_list)):
        if pos_list_2[i]<u_list[j]:
            i+=1
        elif pos_list_2[i]>u_list[j]:
            not_pos_list_2.add(u_list[j])
            j+=1
        else:
            i+=1
            j+=1
        num_of_not_operations+=1
    while(j<len(u_list)):
        not_pos_list_2.add(u_list[j])
        j+=1
    
    result, ops = xORy(pos_list_1, not_pos_list_2)
    return result, num_of_not_operations+ops

# %% [markdown]
# # Main

# %%
def main():
    # create set of stop words for preprocessing
    stopwords_set = set(stopwords.words('english'))
    
    # Get List of Files in Dataset
    list_of_files = getListOfFiles('Dataset/Humor,Hist,Media,Food/')
    
    # create dictionary of file with docID (integer) as key and full_path of file as value
    file_dictionary = create_file_dictionary(list_of_files)
    
    # create unigram inverted index once and then load pickle file afterwards
    #create_unigram_inverted_index(file_dictionary, stopwords_set)
    
    #Loading pre-processed files
    uii_file = open('unigram_inverted_index_pickle_file', 'rb')
    unigram_inverted_index = pickle.load(uii_file)
    uii_file.close()
    u_list = SortedSet()
    for a in range(len(file_dictionary)):
        u_list.add(a)
    
    N = int(input())
    for q in range(N):
        input_sentence = input()
        input_operation_sequence = input()
        sanitized_query = preprocess(input_sentence, stopwords_set, 'query')
        sanitized_operation_sequence = []
        for op_seq in input_operation_sequence.split(','):
            sanitized_operation_sequence.append(op_seq.lower().strip())
        print(sanitized_query)
        print(sanitized_operation_sequence)
        if(len(sanitized_query)!=len(sanitized_operation_sequence)+1):
            print('invalid query')
            continue
        ptr1,ptr2 = 0,0
        result = unigram_inverted_index[sanitized_query[ptr1]][1]
        num_of_operations = 0
        while(ptr2<len(sanitized_operation_sequence)):
            if sanitized_operation_sequence[ptr2]=='and':
                res, ops = xANDy(result, unigram_inverted_index[sanitized_query[ptr1+1]][1])
            elif sanitized_operation_sequence[ptr2]=='or':
                res, ops = xORy(result, unigram_inverted_index[sanitized_query[ptr1+1]][1])
            elif sanitized_operation_sequence[ptr2]=='and not':
                res, ops = xANDNOTy(result, unigram_inverted_index[sanitized_query[ptr1+1]][1])
            elif sanitized_operation_sequence[ptr2]=='or not':
                res, ops = xORNOTy(result, unigram_inverted_index[sanitized_query[ptr1+1]][1], u_list)
            ptr1+=1
            ptr2+=1
            result = res
            num_of_operations += ops
        print('Number of documents matched: {}'.format(len(result)))
        print('Number of comparisons required: {}'.format(num_of_operations))
        print('Documents: \n')
        for res_doc in result:
            print(file_dictionary[res_doc])

# %%
if __name__ == "__main__":
    main()
# Out:
# 1
# brutus$ -- chicken kitchen
# or not, and not
# ['brutus', 'chicken', 'kitchen']
# ['or not', 'and not']
# Number of documents matched: 988
# Number of comparisons required: 3053
# Documents:
#
# Dataset/Humor,Hist,Media,Food/1st_aid.txt
# Dataset/Humor,Hist,Media,Food/a-team
# Dataset/Humor,Hist,Media,Food/abbott.txt
# Dataset/Humor,Hist,Media,Food/aboutada.txt
# Dataset/Humor,Hist,Media,Food/acetab1.txt
# Dataset/Humor,Hist,Media,Food/aclamt.txt
# Dataset/Humor,Hist,Media,Food/acne1.txt
# Dataset/Humor,Hist,Media,Food/acronym.lis
# Dataset/Humor,Hist,Media,Food/acronym.txt
# Dataset/Humor,Hist,Media,Food/adameve.hum
# Dataset/Humor,Hist,Media,Food/adcopy.hum
# Dataset/Humor,Hist,Media,Food/addrmeri.txt
# Dataset/Humor,Hist,Media,Food/admin.txt
# Dataset/Humor,Hist,Media,Food/adrian_e.faq
# Dataset/Humor,Hist,Media,Food/adt_miam.txt
# Dataset/Humor,Hist,Media,Food/aeonint.txt
# Dataset/Humor,Hist,Media,Food/age.txt
# Dataset/Humor,Hist,Media,Food/aggie.txt
# Dataset/Humor,Hist,Media,Food/aids.txt
# Dataset/Humor,Hist,Media,Food/airlines
# Dataset/Humor,Hist,Media,Food/alabama.txt
# Dataset/Humor,Hist,Media,Food/alcatax.txt
# Dataset/Humor,Hist,Media,Food/alcohol.hum
# Dataset/Humor,Hist,Media,Food/alflog.txt
# Dataset/Humor,Hist,Media,Food/allusion
# Dataset/Humor,Hist,Media,Food/amazing.epi
# Dataset/Humor,Hist,Media,Food/ambrose.bie
# Dataset/Humor,Hist,Media,Food/amchap2.txt
# Dataset/Humor,Hist,Media,Food/analogy.hum
# Dataset/Humor,Hist,Media,Food/aniherb.txt
# Dataset/Humor,Hist,Media,Food/anime.cli
# Dataset/Humor,Hist,Media,Food/anime.lif
# Dataset/Humor,Hist,Media,Food/anim_lif.txt
# Dataset/Humor,Hist,Media,Food/annoy.fascist
# Dataset/Humor,Hist,Media,Food/anorexia.txt
# Dataset/Humor,Hist,Media,Food/answers
# Dataset/Humor,Hist,Media,Food/anthropo.stu
# Dataset/Humor,Hist,Media,Food/antibiot.txt
# Dataset/Humor,Hist,Media,Food/antimead.bev
# Dataset/Humor,Hist,Media,Food/aphrodis.txt
# Dataset/Humor,Hist,Media,Food/appbred.brd
# Dataset/Humor,Hist,Media,Food/applepie.des
# Dataset/Humor,Hist,Media,Food/apsaucke.des
# Dataset/Humor,Hist,Media,Food/apsnet.txt
# Dataset/Humor,Hist,Media,Food/arab.dic
# Dataset/Humor,Hist,Media,Food/arcadian.txt
# Dataset/Humor,Hist,Media,Food/argotdic.txt
# Dataset/Humor,Hist,Media,Food/arnold.txt
# Dataset/Humor,Hist,Media,Food/art-fart.hum
# Dataset/Humor,Hist,Media,Food/arthriti.txt
# Dataset/Humor,Hist,Media,Food/ateam.epi
# Dataset/Humor,Hist,Media,Food/atherosc.txt
# Dataset/Humor,Hist,Media,Food/att.txt
# Dataset/Humor,Hist,Media,Food/avengers.lis
# Dataset/Humor,Hist,Media,Food/awespinh.sal
# Dataset/Humor,Hist,Media,Food/ayurved.txt
# Dataset/Humor,Hist,Media,Food/a_fish_c.apo
# Dataset/Humor,Hist,Media,Food/a_tv_t-p.com
# Dataset/Humor,Hist,Media,Food/b-2.jok
# Dataset/Humor,Hist,Media,Food/b12.txt
# Dataset/Humor,Hist,Media,Food/back1.txt
# Dataset/Humor,Hist,Media,Food/bad-d
# Dataset/Humor,Hist,Media,Food/bad.jok
# Dataset/Humor,Hist,Media,Food/badday.hum
# Dataset/Humor,Hist,Media,Food/bagelope.txt
# Dataset/Humor,Hist,Media,Food/bakebred.txt
# Dataset/Humor,Hist,Media,Food/baklava.des
# Dataset/Humor,Hist,Media,Food/banana01.brd
# Dataset/Humor,Hist,Media,Food/banana02.brd
# Dataset/Humor,Hist,Media,Food/banana03.brd
# Dataset/Humor,Hist,Media,Food/banana04.brd
# Dataset/Humor,Hist,Media,Food/banana05.brd
# Dataset/Humor,Hist,Media,Food/bank.rob
# Dataset/Humor,Hist,Media,Food/barney.cn1
# Dataset/Humor,Hist,Media,Food/basehead.txt
# Dataset/Humor,Hist,Media,Food/batrbred.txt
# Dataset/Humor,Hist,Media,Food/bb
# Dataset/Humor,Hist,Media,Food/bbc_vide.cat
# Dataset/Humor,Hist,Media,Food/bbq.txt
# Dataset/Humor,Hist,Media,Food/beapimp.hum
# Dataset/Humor,Hist,Media,Food/beave.hum
# Dataset/Humor,Hist,Media,Food/beer-g
# Dataset/Humor,Hist,Media,Food/beer-gui
# Dataset/Humor,Hist,Media,Food/beer.gam
# Dataset/Humor,Hist,Media,Food/beer.hum
# Dataset/Humor,Hist,Media,Food/beer.txt
# Dataset/Humor,Hist,Media,Food/beerdiag.txt
# Dataset/Humor,Hist,Media,Food/beergame.hum
# Dataset/Humor,Hist,Media,Food/beergame.txt
# Dataset/Humor,Hist,Media,Food/beerjesus.hum
# Dataset/Humor,Hist,Media,Food/beershrm.fis
# Dataset/Humor,Hist,Media,Food/beershrp.fis
# Dataset/Humor,Hist,Media,Food/beerwarn.txt
# Dataset/Humor,Hist,Media,Food/beesherb.txt
# Dataset/Humor,Hist,Media,Food/beginn.ers
# Dataset/Humor,Hist,Media,Food/berryeto.bev
# Dataset/Humor,Hist,Media,Food/bhang.fun
# Dataset/Humor,Hist,Media,Food/bhb.ill
# Dataset/Humor,Hist,Media,Food/bible.txt
# Dataset/Humor,Hist,Media,Food/bigpic1.hum
# Dataset/Humor,Hist,Media,Food/billcat.hum
# Dataset/Humor,Hist,Media,Food/bimg.prn
# Dataset/Humor,Hist,Media,Food/bingbong.hum
# Dataset/Humor,Hist,Media,Food/bitchcar.hum
# Dataset/Humor,Hist,Media,Food/bitnet.txt
# Dataset/Humor,Hist,Media,Food/blackadd
# Dataset/Humor,Hist,Media,Food/blackhol.hum
# Dataset/Humor,Hist,Media,Food/blake7.lis
# Dataset/Humor,Hist,Media,Food/blaster.hum
# Dataset/Humor,Hist,Media,Food/bless.bc
# Dataset/Humor,Hist,Media,Food/blkbean.txt
# Dataset/Humor,Hist,Media,Food/blkbnsrc.vgn
# Dataset/Humor,Hist,Media,Food/blood.txt
# Dataset/Humor,Hist,Media,Food/blooprs1.asc
# Dataset/Humor,Hist,Media,Food/boarchil.txt
# Dataset/Humor,Hist,Media,Food/boatmemo.jok
# Dataset/Humor,Hist,Media,Food/boe.hum
# Dataset/Humor,Hist,Media,Food/bond-2.txt
# Dataset/Humor,Hist,Media,Food/booze.fun
# Dataset/Humor,Hist,Media,Food/booze1.fun
# Dataset/Humor,Hist,Media,Food/booze2.fun
# Dataset/Humor,Hist,Media,Food/boston.geog
# Dataset/Humor,Hist,Media,Food/bozo_tv.leg
# Dataset/Humor,Hist,Media,Food/brainect.hum
# Dataset/Humor,Hist,Media,Food/brdpudd.des
# Dataset/Humor,Hist,Media,Food/bread.rec
# Dataset/Humor,Hist,Media,Food/bread.txt
# Dataset/Humor,Hist,Media,Food/breadpud.des
# Dataset/Humor,Hist,Media,Food/bredcake.des
# Dataset/Humor,Hist,Media,Food/brewing
# Dataset/Humor,Hist,Media,Food/browneco.hum
# Dataset/Humor,Hist,Media,Food/brownie.rec
# Dataset/Humor,Hist,Media,Food/brush1.txt
# Dataset/Humor,Hist,Media,Food/btaco.txt
# Dataset/Humor,Hist,Media,Food/btcisfre.hum
# Dataset/Humor,Hist,Media,Food/btscke01.des
# Dataset/Humor,Hist,Media,Food/btscke02.des
# Dataset/Humor,Hist,Media,Food/btscke03.des
# Dataset/Humor,Hist,Media,Food/btscke04.des
# Dataset/Humor,Hist,Media,Food/btscke05.des
# Dataset/Humor,Hist,Media,Food/bugbreak.hum
# Dataset/Humor,Hist,Media,Food/bugs.txt
# Dataset/Humor,Hist,Media,Food/buldrwho.txt
# Dataset/Humor,Hist,Media,Food/bunacald.fis
# Dataset/Humor,Hist,Media,Food/burrito.mea
# Dataset/Humor,Hist,Media,Food/butcher.txt
# Dataset/Humor,Hist,Media,Food/butstcod.fis
# Dataset/Humor,Hist,Media,Food/butwrong.hum
# Dataset/Humor,Hist,Media,Food/buzzword.hum
# Dataset/Humor,Hist,Media,Food/bw-phwan.hat
# Dataset/Humor,Hist,Media,Food/bw-summe.hat
# Dataset/Humor,Hist,Media,Food/bw.txt
# Dataset/Humor,Hist,Media,Food/byfb.txt
# Dataset/Humor,Hist,Media,Food/c0dez.txt
# Dataset/Humor,Hist,Media,Food/caesardr.sal
# Dataset/Humor,Hist,Media,Food/cake.rec
# Dataset/Humor,Hist,Media,Food/calamus.hrb
# Dataset/Humor,Hist,Media,Food/calculus.txt
# Dataset/Humor,Hist,Media,Food/calif.hum
# Dataset/Humor,Hist,Media,Food/cancer.rat
# Dataset/Humor,Hist,Media,Food/candybar.fun
# Dataset/Humor,Hist,Media,Food/capital.txt
# Dataset/Humor,Hist,Media,Food/caramels.des
# Dataset/Humor,Hist,Media,Food/carowner.txt
# Dataset/Humor,Hist,Media,Food/cars.txt
# Dataset/Humor,Hist,Media,Food/cartoon.law
# Dataset/Humor,Hist,Media,Food/cartoon.laws
# Dataset/Humor,Hist,Media,Food/cartoon_.txt
# Dataset/Humor,Hist,Media,Food/cartoon_laws.txt
# Dataset/Humor,Hist,Media,Food/cartwb.son
# Dataset/Humor,Hist,Media,Food/cast.lis
# Dataset/Humor,Hist,Media,Food/catballs.hum
# Dataset/Humor,Hist,Media,Food/catin.hat
# Dataset/Humor,Hist,Media,Food/catranch.hum
# Dataset/Humor,Hist,Media,Food/catstory.txt
# Dataset/Humor,Hist,Media,Food/cbmatic.hum
# Dataset/Humor,Hist,Media,Food/cereal.txt
# Dataset/Humor,Hist,Media,Food/cform2.txt
# Dataset/Humor,Hist,Media,Food/cgs_lst.txt
# Dataset/Humor,Hist,Media,Food/chainltr.txt
# Dataset/Humor,Hist,Media,Food/change.hum
# Dataset/Humor,Hist,Media,Food/charity.hum
# Dataset/Humor,Hist,Media,Food/cheapfar.hum
# Dataset/Humor,Hist,Media,Food/cheapin.la
# Dataset/Humor,Hist,Media,Food/chickenheadbbs.txt
# Dataset/Humor,Hist,Media,Food/childrenbooks.txt
# Dataset/Humor,Hist,Media,Food/chinese.txt
# Dataset/Humor,Hist,Media,Food/chinesec.hum
# Dataset/Humor,Hist,Media,Food/choco-ch.ips
# Dataset/Humor,Hist,Media,Food/christop.int
# Dataset/Humor,Hist,Media,Food/chung.iv
# Dataset/Humor,Hist,Media,Food/chunnel.txt
# Dataset/Humor,Hist,Media,Food/church.sto
# Dataset/Humor,Hist,Media,Food/clancy.txt
# Dataset/Humor,Hist,Media,Food/classicm.hum
# Dataset/Humor,Hist,Media,Food/climbing.let
# Dataset/Humor,Hist,Media,Food/cmu.share
# Dataset/Humor,Hist,Media,Food/co-car.jok
# Dataset/Humor,Hist,Media,Food/cockney.alp
# Dataset/Humor,Hist,Media,Food/coffee.txt
# Dataset/Humor,Hist,Media,Food/coffeebeerwomen.txt
# Dataset/Humor,Hist,Media,Food/cogdis.txt
# Dataset/Humor,Hist,Media,Food/coke.fun
# Dataset/Humor,Hist,Media,Food/coke.txt
# Dataset/Humor,Hist,Media,Food/cokeform.txt
# Dataset/Humor,Hist,Media,Food/coke_fan.naz
# Dataset/Humor,Hist,Media,Food/coladrik.fun
# Dataset/Humor,Hist,Media,Food/coladrik.txt
# Dataset/Humor,Hist,Media,Food/cold.fus
# Dataset/Humor,Hist,Media,Food/coldfake.hum
# Dataset/Humor,Hist,Media,Food/collected_quotes.txt
# Dataset/Humor,Hist,Media,Food/college.hum
# Dataset/Humor,Hist,Media,Food/college.sla
# Dataset/Humor,Hist,Media,Food/college.txt
# Dataset/Humor,Hist,Media,Food/comic_st.gui
# Dataset/Humor,Hist,Media,Food/commutin.jok
# Dataset/Humor,Hist,Media,Food/commword.hum
# Dataset/Humor,Hist,Media,Food/computer.txt
# Dataset/Humor,Hist,Media,Food/comrevi1.hum
# Dataset/Humor,Hist,Media,Food/conan.txt
# Dataset/Humor,Hist,Media,Food/confucius_say.txt
# Dataset/Humor,Hist,Media,Food/contract.moo
# Dataset/Humor,Hist,Media,Food/cookberk
# Dataset/Humor,Hist,Media,Food/cookbkly.how
# Dataset/Humor,Hist,Media,Food/cookie.1
# Dataset/Humor,Hist,Media,Food/cooking.fun
# Dataset/Humor,Hist,Media,Food/coollngo2.txt
# Dataset/Humor,Hist,Media,Food/cooplaws
# Dataset/Humor,Hist,Media,Food/cops.txt
# Dataset/Humor,Hist,Media,Food/corporat.txt
# Dataset/Humor,Hist,Media,Food/court.quips
# Dataset/Humor,Hist,Media,Food/cowexplo.hum
# Dataset/Humor,Hist,Media,Food/coyote.txt
# Dataset/Humor,Hist,Media,Food/crazy.txt
# Dataset/Humor,Hist,Media,Food/critic.txt
# Dataset/Humor,Hist,Media,Food/crzycred.lst
# Dataset/Humor,Hist,Media,Food/cucumber.jok
# Dataset/Humor,Hist,Media,Food/cucumber.txt
# Dataset/Humor,Hist,Media,Food/cultmov.faq
# Dataset/Humor,Hist,Media,Food/curse.txt
# Dataset/Humor,Hist,Media,Food/d-ned.hum
# Dataset/Humor,Hist,Media,Food/dalive
# Dataset/Humor,Hist,Media,Food/damiana.hrb
# Dataset/Humor,Hist,Media,Food/dandwine.bev
# Dataset/Humor,Hist,Media,Food/dark.suc
# Dataset/Humor,Hist,Media,Food/dead-r
# Dataset/Humor,Hist,Media,Food/dead2.txt
# Dataset/Humor,Hist,Media,Food/dead3.txt
# Dataset/Humor,Hist,Media,Food/deadlysins.txt
# Dataset/Humor,Hist,Media,Food/deathhem.txt
# Dataset/Humor,Hist,Media,Food/deep.txt
# Dataset/Humor,Hist,Media,Food/defectiv.hum
# Dataset/Humor,Hist,Media,Food/desk.txt
# Dataset/Humor,Hist,Media,Food/deterior.hum
# Dataset/Humor,Hist,Media,Food/diesmurf.txt
# Dataset/Humor,Hist,Media,Food/diet.txt
# Dataset/Humor,Hist,Media,Food/dieter.txt
# Dataset/Humor,Hist,Media,Food/dingding.hum
# Dataset/Humor,Hist,Media,Food/disaster.hum
# Dataset/Humor,Hist,Media,Food/disclmr.txt
# Dataset/Humor,Hist,Media,Food/disclym.txt
# Dataset/Humor,Hist,Media,Food/doc-says.txt
# Dataset/Humor,Hist,Media,Food/docdict.txt
# Dataset/Humor,Hist,Media,Food/docspeak.txt
# Dataset/Humor,Hist,Media,Food/doggun.sto
# Dataset/Humor,Hist,Media,Food/donut.txt
# Dataset/Humor,Hist,Media,Food/dover.poem
# Dataset/Humor,Hist,Media,Food/draxamus.txt
# Dataset/Humor,Hist,Media,Food/drinker.txt
# Dataset/Humor,Hist,Media,Food/drinking.tro
# Dataset/Humor,Hist,Media,Food/drinkrul.jok
# Dataset/Humor,Hist,Media,Food/drinks.gui
# Dataset/Humor,Hist,Media,Food/drinks.txt
# Dataset/Humor,Hist,Media,Food/drive.txt
# Dataset/Humor,Hist,Media,Food/dromes.txt
# Dataset/Humor,Hist,Media,Food/druggame.hum
# Dataset/Humor,Hist,Media,Food/drugshum.hum
# Dataset/Humor,Hist,Media,Food/drunk.txt
# Dataset/Humor,Hist,Media,Food/dthought.txt
# Dataset/Humor,Hist,Media,Food/dubltalk.jok
# Dataset/Humor,Hist,Media,Food/eandb.drx
# Dataset/Humor,Hist,Media,Food/earp
# Dataset/Humor,Hist,Media,Food/econridl.fun
# Dataset/Humor,Hist,Media,Food/egg-bred.txt
# Dataset/Humor,Hist,Media,Food/egglentl.vgn
# Dataset/Humor,Hist,Media,Food/eggroll1.mea
# Dataset/Humor,Hist,Media,Food/electric.txt
# Dataset/Humor,Hist,Media,Food/element.jok
# Dataset/Humor,Hist,Media,Food/elephant.fun
# Dataset/Humor,Hist,Media,Food/elevator.fun
# Dataset/Humor,Hist,Media,Food/empeval.txt
# Dataset/Humor,Hist,Media,Food/engineer.hum
# Dataset/Humor,Hist,Media,Food/english.txt
# Dataset/Humor,Hist,Media,Food/engmuffn.txt
# Dataset/Humor,Hist,Media,Food/engrhyme.txt
# Dataset/Humor,Hist,Media,Food/enlightenment.txt
# Dataset/Humor,Hist,Media,Food/enquire.hum
# Dataset/Humor,Hist,Media,Food/epiquest.txt
# Dataset/Humor,Hist,Media,Food/episimp2.txt
# Dataset/Humor,Hist,Media,Food/epitaph
# Dataset/Humor,Hist,Media,Food/epi_.txt
# Dataset/Humor,Hist,Media,Food/epi_merm.txt
# Dataset/Humor,Hist,Media,Food/eskimo.nel
# Dataset/Humor,Hist,Media,Food/exam.50
# Dataset/Humor,Hist,Media,Food/excuse.txt
# Dataset/Humor,Hist,Media,Food/excuse30.txt
# Dataset/Humor,Hist,Media,Food/excuses.txt
# Dataset/Humor,Hist,Media,Food/exidy.txt
# Dataset/Humor,Hist,Media,Food/exylic.txt
# Dataset/Humor,Hist,Media,Food/failure.txt
# Dataset/Humor,Hist,Media,Food/farsi.phrase
# Dataset/Humor,Hist,Media,Food/farsi.txt
# Dataset/Humor,Hist,Media,Food/fartinfo.txt
# Dataset/Humor,Hist,Media,Food/fartting.txt
# Dataset/Humor,Hist,Media,Food/fascist.txt
# Dataset/Humor,Hist,Media,Food/fbipizza.txt
# Dataset/Humor,Hist,Media,Food/fed.txt
# Dataset/Humor,Hist,Media,Food/fegg!int.txt
# Dataset/Humor,Hist,Media,Food/feggaqui.txt
# Dataset/Humor,Hist,Media,Food/feggmagi.txt
# Dataset/Humor,Hist,Media,Food/feista01.dip
# Dataset/Humor,Hist,Media,Food/female.jok
# Dataset/Humor,Hist,Media,Food/figure_1.txt
# Dataset/Humor,Hist,Media,Food/filmgoof.txt
# Dataset/Humor,Hist,Media,Food/final-ex.txt
# Dataset/Humor,Hist,Media,Food/finalexm.hum
# Dataset/Humor,Hist,Media,Food/firecamp.txt
# Dataset/Humor,Hist,Media,Food/fireplacein.txt
# Dataset/Humor,Hist,Media,Food/firstaid.inf
# Dataset/Humor,Hist,Media,Food/firstaid.txt
# Dataset/Humor,Hist,Media,Food/fish.rec
# Dataset/Humor,Hist,Media,Food/flattax.hum
# Dataset/Humor,Hist,Media,Food/flowchrt
# Dataset/Humor,Hist,Media,Food/flowchrt.txt
# Dataset/Humor,Hist,Media,Food/flux_fix.txt
# Dataset/Humor,Hist,Media,Food/focaccia.brd
# Dataset/Humor,Hist,Media,Food/footfun.hum
# Dataset/Humor,Hist,Media,Food/forsooth.hum
# Dataset/Humor,Hist,Media,Food/free-cof.fee
# Dataset/Humor,Hist,Media,Food/freshman.hum
# Dataset/Humor,Hist,Media,Food/freudonseuss.txt
# Dataset/Humor,Hist,Media,Food/frogeye1.sal
# Dataset/Humor,Hist,Media,Food/from.hum
# Dataset/Humor,Hist,Media,Food/fuck!.txt
# Dataset/Humor,Hist,Media,Food/fuckyou2.txt
# Dataset/Humor,Hist,Media,Food/fusion.gal
# Dataset/Humor,Hist,Media,Food/fwksfun.hum
# Dataset/Humor,Hist,Media,Food/f_tang.txt
# Dataset/Humor,Hist,Media,Food/gack!.txt
# Dataset/Humor,Hist,Media,Food/gaiahuma
# Dataset/Humor,Hist,Media,Food/gameshow.txt
# Dataset/Humor,Hist,Media,Food/ganamembers.txt
# Dataset/Humor,Hist,Media,Food/garlpast.vgn
# Dataset/Humor,Hist,Media,Food/gas.txt
# Dataset/Humor,Hist,Media,Food/gd_drwho.txt
# Dataset/Humor,Hist,Media,Food/gd_flybd.txt
# Dataset/Humor,Hist,Media,Food/gd_frasr.txt
# Dataset/Humor,Hist,Media,Food/gd_guide.txt
# Dataset/Humor,Hist,Media,Food/gd_hhead.txt
# Dataset/Humor,Hist,Media,Food/gd_liqtv.txt
# Dataset/Humor,Hist,Media,Food/gd_maxhd.txt
# Dataset/Humor,Hist,Media,Food/gd_ol.txt
# Dataset/Humor,Hist,Media,Food/gd_sgrnd.txt
# Dataset/Humor,Hist,Media,Food/gd_tznew.txt
# Dataset/Humor,Hist,Media,Food/german.aut
# Dataset/Humor,Hist,Media,Food/get.drunk.cheap
# Dataset/Humor,Hist,Media,Food/ghostfun.hum
# Dataset/Humor,Hist,Media,Food/gingbeer.txt
# Dataset/Humor,Hist,Media,Food/godmonth.txt
# Dataset/Humor,Hist,Media,Food/goforth.hum
# Dataset/Humor,Hist,Media,Food/gohome.hum
# Dataset/Humor,Hist,Media,Food/goldwatr.txt
# Dataset/Humor,Hist,Media,Food/good.txt
# Dataset/Humor,Hist,Media,Food/gotukola.hrb
# Dataset/Humor,Hist,Media,Food/gown.txt
# Dataset/Humor,Hist,Media,Food/grammar.jok
# Dataset/Humor,Hist,Media,Food/grommet.hum
# Dataset/Humor,Hist,Media,Food/grospoem.txt
# Dataset/Humor,Hist,Media,Food/growth.txt
# Dataset/Humor,Hist,Media,Food/gumbo.txt
# Dataset/Humor,Hist,Media,Food/hack
# Dataset/Humor,Hist,Media,Food/hack7.txt
# Dataset/Humor,Hist,Media,Food/hackingcracking.txt
# Dataset/Humor,Hist,Media,Food/hackmorality.txt
# Dataset/Humor,Hist,Media,Food/hacktest.txt
# Dataset/Humor,Hist,Media,Food/hamburge.nam
# Dataset/Humor,Hist,Media,Food/hangover.txt
# Dataset/Humor,Hist,Media,Food/happyhack.txt
# Dataset/Humor,Hist,Media,Food/hate.hum
# Dataset/Humor,Hist,Media,Food/hbo_spec.rev
# Dataset/Humor,Hist,Media,Food/headlnrs
# Dataset/Humor,Hist,Media,Food/hecomes.jok
# Dataset/Humor,Hist,Media,Food/hedgehog.txt
# Dataset/Humor,Hist,Media,Food/height.txt
# Dataset/Humor,Hist,Media,Food/hell.jok
# Dataset/Humor,Hist,Media,Food/hell.txt
# Dataset/Humor,Hist,Media,Food/herb!.hum
# Dataset/Humor,Hist,Media,Food/hermsys.txt
# Dataset/Humor,Hist,Media,Food/heroic.txt
# Dataset/Humor,Hist,Media,Food/hierarch.txt
# Dataset/Humor,Hist,Media,Food/highland.epi
# Dataset/Humor,Hist,Media,Food/hilbilly.wri
# Dataset/Humor,Hist,Media,Food/history2.oop
# Dataset/Humor,Hist,Media,Food/hitchcoc.app
# Dataset/Humor,Hist,Media,Food/hitchcok.txt
# Dataset/Humor,Hist,Media,Food/hitler.59
# Dataset/Humor,Hist,Media,Food/hitler.txt
# Dataset/Humor,Hist,Media,Food/hitlerap.txt
# Dataset/Humor,Hist,Media,Food/homebrew.txt
# Dataset/Humor,Hist,Media,Food/hoonsrc.txt
# Dataset/Humor,Hist,Media,Food/hoosier.txt
# Dataset/Humor,Hist,Media,Food/horflick.txt
# Dataset/Humor,Hist,Media,Food/horoscop.jok
# Dataset/Humor,Hist,Media,Food/horoscop.txt
# Dataset/Humor,Hist,Media,Food/horoscope.txt
# Dataset/Humor,Hist,Media,Food/hotel.txt
# Dataset/Humor,Hist,Media,Food/hotnnot.hum
# Dataset/Humor,Hist,Media,Food/hotpeper.txt
# Dataset/Humor,Hist,Media,Food/how.bugs.breakd
# Dataset/Humor,Hist,Media,Food/how_to_i.pro
# Dataset/Humor,Hist,Media,Food/hstlrtxt.txt
# Dataset/Humor,Hist,Media,Food/htswfren.txt
# Dataset/Humor,Hist,Media,Food/hum2
# Dataset/Humor,Hist,Media,Food/humatra.txt
# Dataset/Humor,Hist,Media,Food/humatran.jok
# Dataset/Humor,Hist,Media,Food/humpty.dumpty
# Dataset/Humor,Hist,Media,Food/iced.tea
# Dataset/Humor,Hist,Media,Food/icm.hum
# Dataset/Humor,Hist,Media,Food/idaho.txt
# Dataset/Humor,Hist,Media,Food/idr2.txt
# Dataset/Humor,Hist,Media,Food/imbecile.txt
# Dataset/Humor,Hist,Media,Food/imprrisk.hum
# Dataset/Humor,Hist,Media,Food/impurmat.hum
# Dataset/Humor,Hist,Media,Food/incarhel.hum
# Dataset/Humor,Hist,Media,Food/indgrdn.txt
# Dataset/Humor,Hist,Media,Food/initials.rid
# Dataset/Humor,Hist,Media,Food/inquirer.txt
# Dataset/Humor,Hist,Media,Food/ins1
# Dataset/Humor,Hist,Media,Food/insanity.hum
# Dataset/Humor,Hist,Media,Food/insect1.txt
# Dataset/Humor,Hist,Media,Food/insult
# Dataset/Humor,Hist,Media,Food/insults1.txt
# Dataset/Humor,Hist,Media,Food/insuranc.sty
# Dataset/Humor,Hist,Media,Food/insure.hum
# Dataset/Humor,Hist,Media,Food/interv.hum
# Dataset/Humor,Hist,Media,Food/investi.hum
# Dataset/Humor,Hist,Media,Food/iqtest
# Dataset/Humor,Hist,Media,Food/iremember
# Dataset/Humor,Hist,Media,Food/is_story.txt
# Dataset/Humor,Hist,Media,Food/italoink.txt
# Dataset/Humor,Hist,Media,Food/ivan.hum
# Dataset/Humor,Hist,Media,Food/jac&tuu.hum
# Dataset/Humor,Hist,Media,Food/jalapast.dip
# Dataset/Humor,Hist,Media,Food/japantv.txt
# Dataset/Humor,Hist,Media,Food/japice.bev
# Dataset/Humor,Hist,Media,Food/japrap.hum
# Dataset/Humor,Hist,Media,Food/jargon.phd
# Dataset/Humor,Hist,Media,Food/jawgumbo.fis
# Dataset/Humor,Hist,Media,Food/jawsalad.fis
# Dataset/Humor,Hist,Media,Food/jayjay.txt
# Dataset/Humor,Hist,Media,Food/jc-elvis.inf
# Dataset/Humor,Hist,Media,Food/jeffie.heh
# Dataset/Humor,Hist,Media,Food/jimhood.txt
# Dataset/Humor,Hist,Media,Food/johann
# Dataset/Humor,Hist,Media,Food/jokeju07.txt
# Dataset/Humor,Hist,Media,Food/jokes1.txt
# Dataset/Humor,Hist,Media,Food/jon.txt
# Dataset/Humor,Hist,Media,Food/jrrt.riddle
# Dataset/Humor,Hist,Media,Food/jungjuic.bev
# Dataset/Humor,Hist,Media,Food/just2
# Dataset/Humor,Hist,Media,Food/justify
# Dataset/Humor,Hist,Media,Food/kaboom.hum
# Dataset/Humor,Hist,Media,Food/kanalx.txt
# Dataset/Humor,Hist,Media,Food/kid2
# Dataset/Humor,Hist,Media,Food/killer.hum
# Dataset/Humor,Hist,Media,Food/killself.hum
# Dataset/Humor,Hist,Media,Food/kilroy
# Dataset/Humor,Hist,Media,Food/kilsmur.hum
# Dataset/Humor,Hist,Media,Food/kloo.txt
# Dataset/Humor,Hist,Media,Food/koans.txt
# Dataset/Humor,Hist,Media,Food/lampoon.jok
# Dataset/Humor,Hist,Media,Food/languag.jok
# Dataset/Humor,Hist,Media,Food/lansing.txt
# Dataset/Humor,Hist,Media,Food/law.sch
# Dataset/Humor,Hist,Media,Food/lawhunt.txt
# Dataset/Humor,Hist,Media,Food/lawskool.txt
# Dataset/Humor,Hist,Media,Food/lawsuniv.hum
# Dataset/Humor,Hist,Media,Food/lawyer.jok
# Dataset/Humor,Hist,Media,Food/lawyers.txt
# Dataset/Humor,Hist,Media,Food/lazarus.txt
# Dataset/Humor,Hist,Media,Food/la_times.hun
# Dataset/Humor,Hist,Media,Food/lbinter.hum
# Dataset/Humor,Hist,Media,Food/leech.txt
# Dataset/Humor,Hist,Media,Food/legal.hum
# Dataset/Humor,Hist,Media,Food/let.go
# Dataset/Humor,Hist,Media,Food/letgosh.txt
# Dataset/Humor,Hist,Media,Food/letterbx.txt
# Dataset/Humor,Hist,Media,Food/letter_f.sch
# Dataset/Humor,Hist,Media,Food/libraway.txt
# Dataset/Humor,Hist,Media,Food/liceprof.sty
# Dataset/Humor,Hist,Media,Food/lif&love.hum
# Dataset/Humor,Hist,Media,Food/lifeimag.hum
# Dataset/Humor,Hist,Media,Food/lifeinfo.hum
# Dataset/Humor,Hist,Media,Food/lifeonledge.txt
# Dataset/Humor,Hist,Media,Food/limerick.jok
# Dataset/Humor,Hist,Media,Food/lines.jok
# Dataset/Humor,Hist,Media,Food/lion.jok
# Dataset/Humor,Hist,Media,Food/lion.txt
# Dataset/Humor,Hist,Media,Food/lions.cat
# Dataset/Humor,Hist,Media,Food/lipkovits.txt
# Dataset/Humor,Hist,Media,Food/livnware.hum
# Dataset/Humor,Hist,Media,Food/llamas.txt
# Dataset/Humor,Hist,Media,Food/llong.hum
# Dataset/Humor,Hist,Media,Food/lobquad.hum
# Dataset/Humor,Hist,Media,Food/looser.hum
# Dataset/Humor,Hist,Media,Food/losers84.hum
# Dataset/Humor,Hist,Media,Food/losers86.hum
# Dataset/Humor,Hist,Media,Food/lost.txt
# Dataset/Humor,Hist,Media,Food/lotsa.jok
# Dataset/Humor,Hist,Media,Food/lozers
# Dataset/Humor,Hist,Media,Food/lozerzon.hum
# Dataset/Humor,Hist,Media,Food/lozeuser.hum
# Dataset/Humor,Hist,Media,Food/lp-assoc.txt
# Dataset/Humor,Hist,Media,Food/lucky.cha
# Dataset/Humor,Hist,Media,Food/ludeinfo.hum
# Dataset/Humor,Hist,Media,Food/ludeinfo.txt
# Dataset/Humor,Hist,Media,Food/luggage.hum
# Dataset/Humor,Hist,Media,Food/luzerzo2.hum
# Dataset/Humor,Hist,Media,Food/m0dzmen.hum
# Dataset/Humor,Hist,Media,Food/macsfarm.old
# Dataset/Humor,Hist,Media,Food/madhattr.jok
# Dataset/Humor,Hist,Media,Food/madscrib.hum
# Dataset/Humor,Hist,Media,Food/maecenas.hum
# Dataset/Humor,Hist,Media,Food/mailfrag.hum
# Dataset/Humor,Hist,Media,Food/makebeer.hum
# Dataset/Humor,Hist,Media,Food/making_y.wel
# Dataset/Humor,Hist,Media,Food/malechem.txt
# Dataset/Humor,Hist,Media,Food/manager.txt
# Dataset/Humor,Hist,Media,Food/manilla.hum
# Dataset/Humor,Hist,Media,Food/manspace.hum
# Dataset/Humor,Hist,Media,Food/margos.txt
# Dataset/Humor,Hist,Media,Food/marines.hum
# Dataset/Humor,Hist,Media,Food/marriage.hum
# Dataset/Humor,Hist,Media,Food/mash.hum
# Dataset/Humor,Hist,Media,Food/math.1
# Dataset/Humor,Hist,Media,Food/math.2
# Dataset/Humor,Hist,Media,Food/math.far
# Dataset/Humor,Hist,Media,Food/maxheadr
# Dataset/Humor,Hist,Media,Food/mcd.txt
# Dataset/Humor,Hist,Media,Food/meat2.txt
# Dataset/Humor,Hist,Media,Food/meinkamp.hum
# Dataset/Humor,Hist,Media,Food/mel.txt
# Dataset/Humor,Hist,Media,Food/melodram.hum
# Dataset/Humor,Hist,Media,Food/memo.hum
# Dataset/Humor,Hist,Media,Food/memory.hum
# Dataset/Humor,Hist,Media,Food/men&wome.txt
# Dataset/Humor,Hist,Media,Food/mensroom.jok
# Dataset/Humor,Hist,Media,Food/merry.txt
# Dataset/Humor,Hist,Media,Food/miamadvi.hum
# Dataset/Humor,Hist,Media,Food/miami.hum
# Dataset/Humor,Hist,Media,Food/miamimth.txt
# Dataset/Humor,Hist,Media,Food/middle.age
# Dataset/Humor,Hist,Media,Food/mindvox
# Dataset/Humor,Hist,Media,Food/minn.txt
# Dataset/Humor,Hist,Media,Food/miranda.hum
# Dataset/Humor,Hist,Media,Food/misc.1
# Dataset/Humor,Hist,Media,Food/misery.hum
# Dataset/Humor,Hist,Media,Food/missdish
# Dataset/Humor,Hist,Media,Food/missheav.hum
# Dataset/Humor,Hist,Media,Food/mitch.txt
# Dataset/Humor,Hist,Media,Food/modemwld.txt
# Dataset/Humor,Hist,Media,Food/modest.hum
# Dataset/Humor,Hist,Media,Food/modstup
# Dataset/Humor,Hist,Media,Food/mog-history
# Dataset/Humor,Hist,Media,Food/montoys.txt
# Dataset/Humor,Hist,Media,Food/montpyth.hum
# Dataset/Humor,Hist,Media,Food/moonshin
# Dataset/Humor,Hist,Media,Food/moore.txt
# Dataset/Humor,Hist,Media,Food/moslem.txt
# Dataset/Humor,Hist,Media,Food/mothers.txt
# Dataset/Humor,Hist,Media,Food/motrbike.jok
# Dataset/Humor,Hist,Media,Food/mov_rail.txt
# Dataset/Humor,Hist,Media,Food/mowers.txt
# Dataset/Humor,Hist,Media,Food/mr.rogers
# Dataset/Humor,Hist,Media,Food/mrscienc.hum
# Dataset/Humor,Hist,Media,Food/mrsfield
# Dataset/Humor,Hist,Media,Food/msfields.txt
# Dataset/Humor,Hist,Media,Food/msorrow
# Dataset/Humor,Hist,Media,Food/mtm.hum
# Dataset/Humor,Hist,Media,Food/mtv.asc
# Dataset/Humor,Hist,Media,Food/mundane.v2
# Dataset/Humor,Hist,Media,Food/murph.jok
# Dataset/Humor,Hist,Media,Food/murphy.txt
# Dataset/Humor,Hist,Media,Food/mutate.hum
# Dataset/Humor,Hist,Media,Food/mydaywss.hum
# Dataset/Humor,Hist,Media,Food/myheart.hum
# Dataset/Humor,Hist,Media,Food/naivewiz.hum
# Dataset/Humor,Hist,Media,Food/namaste.txt
# Dataset/Humor,Hist,Media,Food/nameisreo.txt
# Dataset/Humor,Hist,Media,Food/namm
# Dataset/Humor,Hist,Media,Food/nasaglenn.txt
# Dataset/Humor,Hist,Media,Food/necropls.txt
# Dataset/Humor,Hist,Media,Food/netmask.txt
# Dataset/Humor,Hist,Media,Food/netnews.10
# Dataset/Humor,Hist,Media,Food/newconst.hum
# Dataset/Humor,Hist,Media,Food/newmex.hum
# Dataset/Humor,Hist,Media,Food/news.hum
# Dataset/Humor,Hist,Media,Food/nigel.1
# Dataset/Humor,Hist,Media,Food/nigel.10
# Dataset/Humor,Hist,Media,Food/nigel.2
# Dataset/Humor,Hist,Media,Food/nigel.3
# Dataset/Humor,Hist,Media,Food/nigel.4
# Dataset/Humor,Hist,Media,Food/nigel.5
# Dataset/Humor,Hist,Media,Food/nigel.6
# Dataset/Humor,Hist,Media,Food/nigel.7
# Dataset/Humor,Hist,Media,Food/nigel10.txt
# Dataset/Humor,Hist,Media,Food/nihgel_8.9
# Dataset/Humor,Hist,Media,Food/nintendo.jok
# Dataset/Humor,Hist,Media,Food/normal.boy
# Dataset/Humor,Hist,Media,Food/normalboy.txt
# Dataset/Humor,Hist,Media,Food/normquot.txt
# Dataset/Humor,Hist,Media,Food/nosuch_nasfic
# Dataset/Humor,Hist,Media,Food/novel.hum
# Dataset/Humor,Hist,Media,Food/nukeplay.hum
# Dataset/Humor,Hist,Media,Food/nukewar.jok
# Dataset/Humor,Hist,Media,Food/nukewar.txt
# Dataset/Humor,Hist,Media,Food/nukwaste
# Dataset/Humor,Hist,Media,Food/number
# Dataset/Humor,Hist,Media,Food/number.killer
# Dataset/Humor,Hist,Media,Food/number_k.ill
# Dataset/Humor,Hist,Media,Food/nurds.hum
# Dataset/Humor,Hist,Media,Food/nysucks.hum
# Dataset/Humor,Hist,Media,Food/nzdrinks.txt
# Dataset/Humor,Hist,Media,Food/o-ttalk.hum
# Dataset/Humor,Hist,Media,Food/oakwood.txt
# Dataset/Humor,Hist,Media,Food/oam-001.txt
# Dataset/Humor,Hist,Media,Food/oam.nfo
# Dataset/Humor,Hist,Media,Food/oasis
# Dataset/Humor,Hist,Media,Food/oatbran.rec
# Dataset/Humor,Hist,Media,Food/odd_to.obs
# Dataset/Humor,Hist,Media,Food/odearakk.hum
# Dataset/Humor,Hist,Media,Food/office.txt
# Dataset/Humor,Hist,Media,Food/ohandre.hum
# Dataset/Humor,Hist,Media,Food/oilgluts.hum
# Dataset/Humor,Hist,Media,Food/old.txt
# Dataset/Humor,Hist,Media,Food/oldeng.hum
# Dataset/Humor,Hist,Media,Food/oldtime.sng
# Dataset/Humor,Hist,Media,Food/oldtime.txt
# Dataset/Humor,Hist,Media,Food/oliver.txt
# Dataset/Humor,Hist,Media,Food/oliver02.txt
# Dataset/Humor,Hist,Media,Food/onan.txt
# Dataset/Humor,Hist,Media,Food/one.par
# Dataset/Humor,Hist,Media,Food/onetoone.hum
# Dataset/Humor,Hist,Media,Food/ookpik.hum
# Dataset/Humor,Hist,Media,Food/opinion.hum
# Dataset/Humor,Hist,Media,Food/oracle.jok
# Dataset/Humor,Hist,Media,Food/orgfrost.bev
# Dataset/Humor,Hist,Media,Food/ourfathr.txt
# Dataset/Humor,Hist,Media,Food/outawork.erl
# Dataset/Humor,Hist,Media,Food/outlimit.txt
# Dataset/Humor,Hist,Media,Food/oxymoron.jok
# Dataset/Humor,Hist,Media,Food/oxymoron.txt
# Dataset/Humor,Hist,Media,Food/ozarks.hum
# Dataset/Humor,Hist,Media,Food/p-law.hum
# Dataset/Humor,Hist,Media,Food/packard.txt
# Dataset/Humor,Hist,Media,Food/paddingurpapers.txt
# Dataset/Humor,Hist,Media,Food/parabl.hum
# Dataset/Humor,Hist,Media,Food/parades.hum
# Dataset/Humor,Hist,Media,Food/parsnip.txt
# Dataset/Humor,Hist,Media,Food/passage.hum
# Dataset/Humor,Hist,Media,Food/passenge.sim
# Dataset/Humor,Hist,Media,Food/pasta001.sal
# Dataset/Humor,Hist,Media,Food/pat.txt
# Dataset/Humor,Hist,Media,Food/pbcookie.des
# Dataset/Humor,Hist,Media,Food/peanuts.txt
# Dataset/Humor,Hist,Media,Food/pecker.txt
# Dataset/Humor,Hist,Media,Food/penisprt.txt
# Dataset/Humor,Hist,Media,Food/pepsideg.txt
# Dataset/Humor,Hist,Media,Food/petshop
# Dataset/Humor,Hist,Media,Food/phony.hum
# Dataset/Humor,Hist,Media,Food/phorse.hum
# Dataset/Humor,Hist,Media,Food/phxbbs-m.txt
# Dataset/Humor,Hist,Media,Food/pickup.lin
# Dataset/Humor,Hist,Media,Food/pickup.txt
# Dataset/Humor,Hist,Media,Food/pipespec.txt
# Dataset/Humor,Hist,Media,Food/planeget.hum
# Dataset/Humor,Hist,Media,Food/planetzero.txt
# Dataset/Humor,Hist,Media,Food/poets.hum
# Dataset/Humor,Hist,Media,Food/pol-corr.txt
# Dataset/Humor,Hist,Media,Food/polemom.txt
# Dataset/Humor,Hist,Media,Food/poli.tics
# Dataset/Humor,Hist,Media,Food/policpig.hum
# Dataset/Humor,Hist,Media,Food/poli_t.ics
# Dataset/Humor,Hist,Media,Food/poll2res.hum
# Dataset/Humor,Hist,Media,Food/polly.txt
# Dataset/Humor,Hist,Media,Food/polly_.new
# Dataset/Humor,Hist,Media,Food/poopie.txt
# Dataset/Humor,Hist,Media,Food/popconc.hum
# Dataset/Humor,Hist,Media,Food/popmach
# Dataset/Humor,Hist,Media,Food/popmusi.hum
# Dataset/Humor,Hist,Media,Food/post.nuc
# Dataset/Humor,Hist,Media,Food/pot.txt
# Dataset/Humor,Hist,Media,Food/potty.txt
# Dataset/Humor,Hist,Media,Food/pournell.spo
# Dataset/Humor,Hist,Media,Food/ppbeer.txt
# Dataset/Humor,Hist,Media,Food/prac1.jok
# Dataset/Humor,Hist,Media,Food/prac3.jok
# Dataset/Humor,Hist,Media,Food/pracjoke.txt
# Dataset/Humor,Hist,Media,Food/prawblim.hum
# Dataset/Humor,Hist,Media,Food/prayer.hum
# Dataset/Humor,Hist,Media,Food/primes.jok
# Dataset/Humor,Hist,Media,Food/princess.brd
# Dataset/Humor,Hist,Media,Food/pro-fact.hum
# Dataset/Humor,Hist,Media,Food/problem.txt
# Dataset/Humor,Hist,Media,Food/progrs.gph
# Dataset/Humor,Hist,Media,Food/proof.met
# Dataset/Humor,Hist,Media,Food/prooftec.txt
# Dataset/Humor,Hist,Media,Food/proposal.jok
# Dataset/Humor,Hist,Media,Food/prover.wisom
# Dataset/Humor,Hist,Media,Food/prover_w.iso
# Dataset/Humor,Hist,Media,Food/psalm.reagan
# Dataset/Humor,Hist,Media,Food/psalm23.txt
# Dataset/Humor,Hist,Media,Food/psalm_nixon
# Dataset/Humor,Hist,Media,Food/psalm_re.aga
# Dataset/Humor,Hist,Media,Food/psilaine.hum
# Dataset/Humor,Hist,Media,Food/psycho.txt
# Dataset/Humor,Hist,Media,Food/psych_pr.quo
# Dataset/Humor,Hist,Media,Food/pure.mat
# Dataset/Humor,Hist,Media,Food/puzzle.spo
# Dataset/Humor,Hist,Media,Food/puzzles.jok
# Dataset/Humor,Hist,Media,Food/python_s.ong
# Dataset/Humor,Hist,Media,Food/q.pun
# Dataset/Humor,Hist,Media,Food/qttofu.vgn
# Dataset/Humor,Hist,Media,Food/quantity.001
# Dataset/Humor,Hist,Media,Food/quantum.jok
# Dataset/Humor,Hist,Media,Food/quantum.phy
# Dataset/Humor,Hist,Media,Food/quest.hum
# Dataset/Humor,Hist,Media,Food/quick.jok
# Dataset/Humor,Hist,Media,Food/quotes.bug
# Dataset/Humor,Hist,Media,Food/quotes.jok
# Dataset/Humor,Hist,Media,Food/quotes.txt
# Dataset/Humor,Hist,Media,Food/quux_p.oem
# Dataset/Humor,Hist,Media,Food/racist.net
# Dataset/Humor,Hist,Media,Food/radexposed.txt
# Dataset/Humor,Hist,Media,Food/radiolaf.hum
# Dataset/Humor,Hist,Media,Food/rapmastr.hum
# Dataset/Humor,Hist,Media,Food/ratings.hum
# Dataset/Humor,Hist,Media,Food/ratspit.hum
# Dataset/Humor,Hist,Media,Food/raven.hum
# Dataset/Humor,Hist,Media,Food/readme.bat
# Dataset/Humor,Hist,Media,Food/reagan.hum
# Dataset/Humor,Hist,Media,Food/realest.txt
# Dataset/Humor,Hist,Media,Food/reasons.txt
# Dataset/Humor,Hist,Media,Food/rec.por
# Dataset/Humor,Hist,Media,Food/recepies.fun
# Dataset/Humor,Hist,Media,Food/recip1.txt
# Dataset/Humor,Hist,Media,Food/recipe.001
# Dataset/Humor,Hist,Media,Food/recipe.002
# Dataset/Humor,Hist,Media,Food/recipe.003
# Dataset/Humor,Hist,Media,Food/recipe.004
# Dataset/Humor,Hist,Media,Food/recipe.006
# Dataset/Humor,Hist,Media,Food/recipe.007
# Dataset/Humor,Hist,Media,Food/recipe.008
# Dataset/Humor,Hist,Media,Food/recipe.009
# Dataset/Humor,Hist,Media,Food/recipe.010
# Dataset/Humor,Hist,Media,Food/recipe.011
# Dataset/Humor,Hist,Media,Food/recipe.012
# Dataset/Humor,Hist,Media,Food/reconcil.hum
# Dataset/Humor,Hist,Media,Food/record_.gap
# Dataset/Humor,Hist,Media,Food/reddwarf.sng
# Dataset/Humor,Hist,Media,Food/reddye.hum
# Dataset/Humor,Hist,Media,Food/rednecks.txt
# Dataset/Humor,Hist,Media,Food/reeves.txt
# Dataset/Humor,Hist,Media,Food/relative.ada
# Dataset/Humor,Hist,Media,Food/renored.txt
# Dataset/Humor,Hist,Media,Food/renorthr.txt
# Dataset/Humor,Hist,Media,Food/rent-a_cat
# Dataset/Humor,Hist,Media,Food/rentals.hum
# Dataset/Humor,Hist,Media,Food/repair.hum
# Dataset/Humor,Hist,Media,Food/report.hum
# Dataset/Humor,Hist,Media,Food/research.hum
# Dataset/Humor,Hist,Media,Food/residncy.jok
# Dataset/Humor,Hist,Media,Food/resolutn.txt
# Dataset/Humor,Hist,Media,Food/resrch_p.hra
# Dataset/Humor,Hist,Media,Food/resrch_phrase
# Dataset/Humor,Hist,Media,Food/revolt.dj
# Dataset/Humor,Hist,Media,Food/richbred.txt
# Dataset/Humor,Hist,Media,Food/rinaldo.jok
# Dataset/Humor,Hist,Media,Food/rinaldos.law
# Dataset/Humor,Hist,Media,Food/rinaldos.txt
# Dataset/Humor,Hist,Media,Food/ripoffpc.hum
# Dataset/Humor,Hist,Media,Food/rns_bcl.txt
# Dataset/Humor,Hist,Media,Food/rns_bwl.txt
# Dataset/Humor,Hist,Media,Food/rns_ency.txt
# Dataset/Humor,Hist,Media,Food/roach.asc
# Dataset/Humor,Hist,Media,Food/roadpizz.txt
# Dataset/Humor,Hist,Media,Food/robot.tes
# Dataset/Humor,Hist,Media,Food/rocking.hum
# Dataset/Humor,Hist,Media,Food/rockmus.hum
# Dataset/Humor,Hist,Media,Food/sanshop.txt
# Dataset/Humor,Hist,Media,Food/saveface.hum
# Dataset/Humor,Hist,Media,Food/sawyer.txt
# Dataset/Humor,Hist,Media,Food/scam.txt
# Dataset/Humor,Hist,Media,Food/seafood.txt
# Dataset/Humor,Hist,Media,Food/seeds42.txt
# Dataset/Humor,Hist,Media,Food/sf-zine.pub
# Dataset/Humor,Hist,Media,Food/sfmovie.txt
# Dataset/Humor,Hist,Media,Food/shameonu.hum
# Dataset/Humor,Hist,Media,Food/shooters.txt
# Dataset/Humor,Hist,Media,Food/shorties.jok
# Dataset/Humor,Hist,Media,Food/shrink.news
# Dataset/Humor,Hist,Media,Food/shuimai.txt
# Dataset/Humor,Hist,Media,Food/shuttleb.hum
# Dataset/Humor,Hist,Media,Food/signatur.jok
# Dataset/Humor,Hist,Media,Food/sigs.txt
# Dataset/Humor,Hist,Media,Food/silverclaws.txt
# Dataset/Humor,Hist,Media,Food/simp.txt
# Dataset/Humor,Hist,Media,Food/sinksub.txt
# Dataset/Humor,Hist,Media,Food/skincat
# Dataset/Humor,Hist,Media,Food/skippy.hum
# Dataset/Humor,Hist,Media,Food/skippy.txt
# Dataset/Humor,Hist,Media,Food/slogans.txt
# Dataset/Humor,Hist,Media,Food/smackjok.hum
# Dataset/Humor,Hist,Media,Food/smartass.txt
# Dataset/Humor,Hist,Media,Food/smiley.txt
# Dataset/Humor,Hist,Media,Food/smokers.txt
# Dataset/Humor,Hist,Media,Food/smurf-03.txt
# Dataset/Humor,Hist,Media,Food/smurfs.cc
# Dataset/Humor,Hist,Media,Food/smurf_co.txt
# Dataset/Humor,Hist,Media,Food/snapple.rum
# Dataset/Humor,Hist,Media,Food/snipe.txt
# Dataset/Humor,Hist,Media,Food/soccer.txt
# Dataset/Humor,Hist,Media,Food/socecon.hum
# Dataset/Humor,Hist,Media,Food/social.hum
# Dataset/Humor,Hist,Media,Food/socks.drx
# Dataset/Humor,Hist,Media,Food/solders.hum
# Dataset/Humor,Hist,Media,Food/solviets.hum
# Dataset/Humor,Hist,Media,Food/some_hu.mor
# Dataset/Humor,Hist,Media,Food/soporifi.abs
# Dataset/Humor,Hist,Media,Food/sorority.gir
# Dataset/Humor,Hist,Media,Food/spacever.hum
# Dataset/Humor,Hist,Media,Food/speling.msk
# Dataset/Humor,Hist,Media,Food/spelin_r.ifo
# Dataset/Humor,Hist,Media,Food/spider.hum
# Dataset/Humor,Hist,Media,Food/spoonlis.txt
# Dataset/Humor,Hist,Media,Food/spydust.hum
# Dataset/Humor,Hist,Media,Food/squids.gph
# Dataset/Humor,Hist,Media,Food/stagline.txt
# Dataset/Humor,Hist,Media,Food/standard.hum
# Dataset/Humor,Hist,Media,Food/startrek.txt
# Dataset/Humor,Hist,Media,Food/stereo.txt
# Dataset/Humor,Hist,Media,Food/steroid.txt
# Dataset/Humor,Hist,Media,Food/stone.hum
# Dataset/Humor,Hist,Media,Food/strattma.txt
# Dataset/Humor,Hist,Media,Food/stressman.txt
# Dataset/Humor,Hist,Media,Food/studentb.txt
# Dataset/Humor,Hist,Media,Food/stuf10.txt
# Dataset/Humor,Hist,Media,Food/stuf11.txt
# Dataset/Humor,Hist,Media,Food/st_silic.txt
# Dataset/Humor,Hist,Media,Food/subb_lis.txt
# Dataset/Humor,Hist,Media,Food/subrdead.hum
# Dataset/Humor,Hist,Media,Food/sungenu.hum
# Dataset/Humor,Hist,Media,Food/swearfrn.hum
# Dataset/Humor,Hist,Media,Food/sw_err.txt
# Dataset/Humor,Hist,Media,Food/symbol.hum
# Dataset/Humor,Hist,Media,Food/sysadmin.txt
# Dataset/Humor,Hist,Media,Food/sysman.txt
# Dataset/Humor,Hist,Media,Food/t-10.hum
# Dataset/Humor,Hist,Media,Food/t-shirt.hum
# Dataset/Humor,Hist,Media,Food/takenote.jok
# Dataset/Humor,Hist,Media,Food/talebeat.hum
# Dataset/Humor,Hist,Media,Food/talkbizr.txt
# Dataset/Humor,Hist,Media,Food/taping.hum
# Dataset/Humor,Hist,Media,Food/tarot.txt
# Dataset/Humor,Hist,Media,Food/teens.txt
# Dataset/Humor,Hist,Media,Food/teevee.hum
# Dataset/Humor,Hist,Media,Food/telecom.q
# Dataset/Humor,Hist,Media,Food/temphell.jok
# Dataset/Humor,Hist,Media,Food/terbear.txt
# Dataset/Humor,Hist,Media,Food/termpoem.txt
# Dataset/Humor,Hist,Media,Food/terms.hum
# Dataset/Humor,Hist,Media,Food/terrnieg.hum
# Dataset/Humor,Hist,Media,Food/test.hum
# Dataset/Humor,Hist,Media,Food/test.jok
# Dataset/Humor,Hist,Media,Food/test2.jok
# Dataset/Humor,Hist,Media,Food/testchri.txt
# Dataset/Humor,Hist,Media,Food/texbeef.txt
# Dataset/Humor,Hist,Media,Food/textgrap.hum
# Dataset/Humor,Hist,Media,Food/tfepisod.hum
# Dataset/Humor,Hist,Media,Food/tfpoems.hum
# Dataset/Humor,Hist,Media,Food/thecube.hum
# Dataset/Humor,Hist,Media,Food/thermite.ana
# Dataset/Humor,Hist,Media,Food/thesis.beh
# Dataset/Humor,Hist,Media,Food/the_ant.txt
# Dataset/Humor,Hist,Media,Food/the_math.hel
# Dataset/Humor,Hist,Media,Food/thievco.txt
# Dataset/Humor,Hist,Media,Food/three.txt
# Dataset/Humor,Hist,Media,Food/throwawa.hum
# Dataset/Humor,Hist,Media,Food/tickmoon.hum
# Dataset/Humor,Hist,Media,Food/timetr.hum
# Dataset/Humor,Hist,Media,Food/tnd.1
# Dataset/Humor,Hist,Media,Food/top10.elf
# Dataset/Humor,Hist,Media,Food/top10st1.txt
# Dataset/Humor,Hist,Media,Food/top10st2.txt
# Dataset/Humor,Hist,Media,Food/toxcwast.hum
# Dataset/Humor,Hist,Media,Food/tpquote2.txt
# Dataset/Humor,Hist,Media,Food/transp.txt
# Dataset/Humor,Hist,Media,Food/trekfume.txt
# Dataset/Humor,Hist,Media,Food/trekwes.hum
# Dataset/Humor,Hist,Media,Food/tribble.hum
# Dataset/Humor,Hist,Media,Food/trukdeth.txt
# Dataset/Humor,Hist,Media,Food/truthlsd.hum
# Dataset/Humor,Hist,Media,Food/truths.hum
# Dataset/Humor,Hist,Media,Food/tshirts.jok
# Dataset/Humor,Hist,Media,Food/tuflife.txt
# Dataset/Humor,Hist,Media,Food/tuna.lab
# Dataset/Humor,Hist,Media,Food/turbo.hum
# Dataset/Humor,Hist,Media,Food/turing.shr
# Dataset/Humor,Hist,Media,Food/twilight.txt
# Dataset/Humor,Hist,Media,Food/twinkie.txt
# Dataset/Humor,Hist,Media,Food/twinkies.jok
# Dataset/Humor,Hist,Media,Food/twinpeak.txt
# Dataset/Humor,Hist,Media,Food/t_zone.jok
# Dataset/Humor,Hist,Media,Food/ukunderg.txt
# Dataset/Humor,Hist,Media,Food/un.happy
# Dataset/Humor,Hist,Media,Food/units.mea
# Dataset/Humor,Hist,Media,Food/univ.odd
# Dataset/Humor,Hist,Media,Food/unochili.txt
# Dataset/Humor,Hist,Media,Food/vaguemag.90s
# Dataset/Humor,Hist,Media,Food/valujet.txt
# Dataset/Humor,Hist,Media,Food/variety1.asc
# Dataset/Humor,Hist,Media,Food/variety2.asc
# Dataset/Humor,Hist,Media,Food/variety3.asc
# Dataset/Humor,Hist,Media,Food/various.txt
# Dataset/Humor,Hist,Media,Food/vegkill.txt
# Dataset/Humor,Hist,Media,Food/venganza.txt
# Dataset/Humor,Hist,Media,Food/venison.txt
# Dataset/Humor,Hist,Media,Food/voltron.hum
# Dataset/Humor,Hist,Media,Food/vonthomp
# Dataset/Humor,Hist,Media,Food/wacky.ani
# Dataset/Humor,Hist,Media,Food/wagit.txt
# Dataset/Humor,Hist,Media,Food/wagon.hum
# Dataset/Humor,Hist,Media,Food/waitress.txt
# Dataset/Humor,Hist,Media,Food/washroom.txt
# Dataset/Humor,Hist,Media,Food/watchlip.hum
# Dataset/Humor,Hist,Media,Food/wedding.hum
# Dataset/Humor,Hist,Media,Food/weight.txt
# Dataset/Humor,Hist,Media,Food/weights.hum
# Dataset/Humor,Hist,Media,Food/welfare
# Dataset/Humor,Hist,Media,Food/welfare.txt
# Dataset/Humor,Hist,Media,Food/wetdream.hum
# Dataset/Humor,Hist,Media,Food/whatbbs
# Dataset/Humor,Hist,Media,Food/whatthe.hum
# Dataset/Humor,Hist,Media,Food/whitbred.txt
# Dataset/Humor,Hist,Media,Food/whoon1st.hum
# Dataset/Humor,Hist,Media,Food/whoops.hum
# Dataset/Humor,Hist,Media,Food/widows
# Dataset/Humor,Hist,Media,Food/wimptest.txt
# Dataset/Humor,Hist,Media,Food/wisconsi.txt
# Dataset/Humor,Hist,Media,Food/wisdom
# Dataset/Humor,Hist,Media,Food/women.jok
# Dataset/Humor,Hist,Media,Food/wood
# Dataset/Humor,Hist,Media,Food/woodbine.txt
# Dataset/Humor,Hist,Media,Food/woodbugs.txt
# Dataset/Humor,Hist,Media,Food/woodsmok.txt
# Dataset/Humor,Hist,Media,Food/woolly_m.amm
# Dataset/Humor,Hist,Media,Food/word.hum
# Dataset/Humor,Hist,Media,Food/wrdnws1.txt
# Dataset/Humor,Hist,Media,Food/wrdnws2.txt
# Dataset/Humor,Hist,Media,Food/wrdnws3.txt
# Dataset/Humor,Hist,Media,Food/wrdnws4.txt
# Dataset/Humor,Hist,Media,Food/wrdnws6.txt
# Dataset/Humor,Hist,Media,Food/wrdnws7.txt
# Dataset/Humor,Hist,Media,Food/wrdnws8.txt
# Dataset/Humor,Hist,Media,Food/wrdnws9.txt
# Dataset/Humor,Hist,Media,Food/x-drinks.txt
# Dataset/Humor,Hist,Media,Food/xibovac.txt
# Dataset/Humor,Hist,Media,Food/xtermin8.hum
# Dataset/Humor,Hist,Media,Food/y.txt
# Dataset/Humor,Hist,Media,Food/yjohncse.hum
# Dataset/Humor,Hist,Media,Food/yogisays.txt
# Dataset/Humor,Hist,Media,Food/yogurt.asc
# Dataset/Humor,Hist,Media,Food/yuban.txt
# Dataset/Humor,Hist,Media,Food/yuppies.hum
# Dataset/Humor,Hist,Media,Food/zen.txt
# Dataset/Humor,Hist,Media,Food/zgtoilet.txt
# Dataset/Humor,Hist,Media,Food/zucantom.sal
# Dataset/Humor,Hist,Media,Food/zuccmush.sal
